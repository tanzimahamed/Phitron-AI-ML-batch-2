# %% [markdown]
# <a href="https://colab.research.google.com/github/tanzimahamed/Phitron-AI-Programming-With-Python-Batch-2/blob/main/Module_2_Function.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def welcome_message():
  print("Hello")

# %% [markdown]
# Calling a Function

# %%
welcome_message() # call a function
# Out:
# Hello

# %% [markdown]
# **Function Names**
# Function names follow the same rules as variable names in Python:
#
# A function name must start with a letter or underscore
# A function name can only contain letters, numbers, and underscores
# Function names are case-sensitive (myFunction and myfunction are different)

# %%
# calculate_sum()
# _private_function()     # Valid function name
# myFunction2()

# %% [markdown]
# # **Why Use Functions?**
# Imagine you need to convert temperatures from Fahrenheit to Celsius several times in your program. Without functions, you would have to write the same calculation code repeatedly:

# %%
temp1 = 77
celsius1 = (temp1 - 32) * 5 / 9
print(celsius1)

temp2 = 95
celsius2 = (temp2 - 32) * 5 / 9
print(celsius2)

temp3 = 50
celsius3 = (temp3 - 32) * 5 / 9
print(celsius3)
# Out:
# 25.0
# 35.0
# 10.0

# %% [markdown]
# With functions - reusable code:

# %%
def fahrenheit_to_celsius(fahrenheit):
  return (fahrenheit - 32) * 5 / 9

print(fahrenheit_to_celsius(77))
print(fahrenheit_to_celsius(95))
print(fahrenheit_to_celsius(50))
# Out:
# 25.0
# 35.0
# 10.0

# %% [markdown]
# ## Return Values
# Functions can send data back to the code that called them using the return statement.
#
# When a function reaches a return statement, it stops executing and sends the result back:

# %%
def get_greeting():
  return "Hello from a function"

message = get_greeting()
print(message)
# Out:
# Hello from a function

# %%
def get_greeting():
  return "Hello from a function"

print(get_greeting())
# Out:
# Hello from a function

# %% [markdown]
# If a function doesn't have a return statement, it returns None by default.

# %%
def add(a, b):
    return a + b

x = add(2, 3)
print(x)
# Out:
# 5

# %%
def test():
    print(5)

x = test()
print(x)
# Out:
# 5
# None

# %%
def test():
    x = 5

print(test())   # None print korbe
# Out:
# None

# %%
def test():
    return 5

x = test()
print(x)
# Out:
# 5

# %%
def calculate_total(price, quantity):
    return price * quantity

total = calculate_total(100, 3)
print("Total:", total)
# Out:
# Total: 300

# %%
def test():
    print(10)        # 10 print korbe
                     # return na thakay None peinr korbe

def test2():
    return 10        # 10 print kobe

a = test()
b = test2()

print(a)
print(b)
# Out:
# 10
# None
# 10

# %%
def check(n):
    if n % 2 == 0:
        print("Even")
    else:
        print("Odd")

result = check(5)
print(result)
# Out:
# Odd
# None

# %%
def check(n):
    if n % 2 == 0:
        return "Even"
    else:
        return "Odd"

result = check(5)
print(result)
# Out:
# Odd

# %%
def multiply(a, b):
    print(a * b)

total = multiply(10, 5)
print("Total:", total)
# Out:
# 50
# Total: None

# %%
def multiply(a, b):
    return a * b

total = multiply(10, 5)
print("Total:", total)
# Out:
# Total: 50

# %%
def test():
    return 10       # return এর পরে code চলে না
    print("Hello")  # ❌ এটা run হবে না

# %% [markdown]
# ## Parameters vs Arguments
# From a function's perspective:
#
# ***A parameter is the variable listed inside the parentheses in the function definition.***
#
# ***An argument is the actual value that is sent to the function when it is called.***

# %%
def my_function(name):         # name is a parameter
  print("Hello", name)

my_function("Emil")            # "Emil" is an argument
# Out:
# Hello Emil

# %% [markdown]
# ***Default Parameter Values***
#
# You can assign default values to parameters. If the function is called without an argument, it uses the default value

# %%
def my_function(country = "Japan"):
  print("I am from", country)

my_function("Bangladesh")
my_function("Inglend")
my_function()
my_function("Brazil")
# Out:
# I am from Bangladesh
# I am from Inglend
# I am from Japan
# I am from Brazil

# %%
def test():
    x = 5

print(test())
# Out:
# None

# %% [markdown]
# # Lambda Function
# Lambda function হলো
#
# একটা ছোট, এক লাইনের (one-line), নামবিহীন (anonymous) function

# %%
# Syntax
lambda arguments: expression

# arguments → input
# expression → output (automatic return)
# Out:
# <function __main__.<lambda>(arguments)>

# %%
add = lambda a, b: a + b
print(add(2, 3))
# Out:
# 5

# %%
print((lambda a, b: a + b)(2, 3))
# Out:
# 5

# %%
def add(a, b):
    return a + b
add(2,3)
# Out:
# 5

# %%
check = lambda x: "Even" if x % 2 == 0 else "Odd"
print(check(5))
# Out:
# Odd

# %% [markdown]
# # *args Function

# %%
def number(*args):
    print(args)

number(1, 2, 3, 4, 5)
# Out:
# (1, 2, 3, 4, 5)

# %% [markdown]
# Without *args:
#
# Problem: fixed number only (3 ta)

# %%
def sum(a, b, c):
    return a + b + c

# %%
def sum_all(*number):
  return sum(number)
print(sum_all(1,2,3,3,7))
print(sum_all(34,67,54))
# Out:
# 16
# 155

# %% [markdown]
# **args = tuple **

# %%
def test (*args):
  print(type(args))
test(2,6,4,4,4,4,4,4,)
# Out:
# <class 'tuple'>

# %% [markdown]
# *args function a loop use

# %%
def show(*args):
  for i in args:
    print(i)

show(1,2,3,4,5)
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
def Student(name, *marks):
  print("Name:",name)
  print("Marks:",marks)
Student("Tanzim Ahamed",90, 78, 85)
# Out:
# Name: Tanzim Ahamed
# Marks: (90, 78, 85)

# %%
def average(*marks):
    return sum(marks) / len(marks)

print(average(80, 90, 100))
print(average(70, 85))
# Out:
# 90.0
# 77.5

# %% [markdown]
# # Nested Function
# A nested function is a function defined inside another function.

# %%
def outer():
    def inner():
        print("Hello World")
    inner()

outer()
# Out:
# Hello World

# %%
def outer():
    x = 10
    def inner():
        print(x)
    inner()

outer()
# Out:
# 10

# %%
def outer():
    def inner(x):
        return x * x
    return inner

square = outer()
print(square(5))
# Out:
# 25

# %%
def outer(a, b):
    def add():
        return a + b

    def sub():
        return a - b

    return add(), sub()

print(outer(5, 2))
# Out:
# (7, 3)

# %%
def outer(x):
    def inner(y):
        return x * y
    return inner

mul = outer(5)
print(mul(3))
# Out:
# 15

# %%
def check():
    def inner(n):
        if n % 2 == 0:
            return "Even"
        else:
            return "Odd"
    return inner

f = check()

print(f(4))
print(f(7))
# Out:
# Even
# Odd

# %%
def decorator(func):
    def inner():
        print("Before")
        func()
        print("After")
    return inner

@decorator
def say_hi():
    print("Hi")

say_hi()
# Out:
# Before
# Hi
# After
