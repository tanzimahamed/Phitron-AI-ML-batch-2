# %% [markdown]
# **Registerd Email:** tanzim.ahamed.bd@gmail.com

# %% [markdown]
# 0) Starter Code (Run First)

# %%
# You must run this code and use this dataset for all questions

import numpy as np
import pandas as pd

np.random.seed(24)

num_employees = 50  # you can increase this if needed

# Employee data
emp_ids = np.arange(101, 101 + num_employees)
emp_ages = np.random.randint(20, 55, num_employees)
emp_income = np.random.randint(35000, 95000, num_employees)

# Fixed set of roles (repetition allowed)
roles_list = [
    "HR Manager",
    "Software Developer",
    "Accountant",
    "Marketing Executive",
    "Sales Executive",
    "Backend Developer",
    "HR Executive",
    "Financial Analyst",
    "Digital Marketer",
    "Operations Manager"
]

emp_roles = np.random.choice(roles_list, num_employees)

# Create DataFrame
data = pd.DataFrame({
    "emp_id": emp_ids,
    "emp_age": emp_ages,
    "emp_salary": emp_income,
    "role": emp_roles
})

# Save dataset
data.to_csv("staff_data.csv", index=False)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
import numpy as np

data_type = emp_ages.dtype
dimensions = emp_ages.ndim
shape_info = emp_ages.shape
total_elements = emp_ages.size


print("Data Type:", data_type)
print("Dimensions:", dimensions)
print("Shape:", shape_info)
print("Total Elements:", total_elements)

print("Data Type:", emp_income.dtype)
print("Shape:", emp_income.shape)
# Out:
# Data Type: int64
# Dimensions: 1
# Shape: (50,)
# Total Elements: 50
# Data Type: int64
# Shape: (50,)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
import numpy as np

# Max salary
max_salary = np.max(emp_income)
# Min salary
min_salary = np.min(emp_income)
# Ave salary
avg_salary = np.mean(emp_income)
# Average age
avg_age = np.mean(emp_ages)

print("Maximum Salary:", max_salary)
print("Minimum Salary:", min_salary)
print("Average Salary:", avg_salary)
print("Average Age:", avg_age)
# Out:
# Maximum Salary: 94722
# Minimum Salary: 35452
# Average Salary: 68409.48
# Average Age: 35.44

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
filtered_data = emp_ages[
    (emp_ages >= 25) &
    (emp_ages <= 40) &
    (emp_income > 50000)]

print("Filtered Ages:")
print(filtered_data)



count_emp = filtered_data.size

print("Total Employees:", count_emp)
# Out:
# Filtered Ages:
# [37 37 35 38 31 29 38 27 32 26 37 26 30 30 27 25 31]
# Total Employees: 17

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
aver_age = np.mean(emp_ages)

updated_ages = np.where(
    emp_ages < aver_age,
    emp_ages + 4,
    emp_ages + 2)

print("Original ages array:")
print(emp_ages)

print("Updated ages array:")
print(updated_ages)

print("Average Age:", aver_age)
# Out:
# Original ages array:
# [54 23 20 43 37 37 21 35 24 38 31 35 29 38 27 45 51 48 20 32 51 53 21 26
#  53 37 26 21 45 30 20 47 53 53 23 24 21 30 27 25 39 20 47 41 22 52 42 54
#  31 50]
# Updated ages array:
# [56 27 24 45 39 39 25 39 28 40 35 39 33 40 31 47 53 50 24 36 53 55 25 30
#  55 39 30 25 47 34 24 49 55 55 27 28 25 34 31 29 41 24 49 43 26 54 44 56
#  35 52]
# Average Age: 35.44

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# Average age
avg_age = np.mean(emp_ages)
# Update ages
new_ages = np.where(emp_ages < avg_age, emp_ages + 4, emp_ages + 2)


print("Original Ages:", emp_ages)
print("Updated Ages :", new_ages)
print("Average Age  :", round(avg_age, 2))
# Out:
# Original Ages: [54 23 20 43 37 37 21 35 24 38 31 35 29 38 27 45 51 48 20 32 51 53 21 26
#  53 37 26 21 45 30 20 47 53 53 23 24 21 30 27 25 39 20 47 41 22 52 42 54
#  31 50]
# Updated Ages : [56 27 24 45 39 39 25 39 28 40 35 39 33 40 31 47 53 50 24 36 53 55 25 30
#  55 39 30 25 47 34 24 49 55 55 27 28 25 34 31 29 41 24 49 43 26 54 44 56
#  35 52]
# Average Age  : 35.44

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
import pandas as pd

# uplode CSv file
df = pd.read_csv("/content/staff_data.csv")



df.head(3)
df.info()
df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   emp_id      50 non-null     int64
#  1   emp_age     50 non-null     int64
#  2   emp_salary  50 non-null     int64
#  3   role        50 non-null     object
# dtypes: int64(3), object(1)
# memory usage: 1.7+ KB
#           emp_id    emp_age    emp_salary
# count   50.00000  50.000000     50.000000
# mean   125.50000  35.440000  68409.480000
# std     14.57738  11.768446  15727.122334
# min    101.00000  20.000000  35452.000000
# 25%    113.25000  24.250000  57309.750000
# 50%    125.50000  35.000000  72037.500000
# 75%    137.75000  46.500000  79512.000000
# max    150.00000  54.000000  94722.000000

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
emp_data = df[["emp_id", "emp_age", "role"]]
emp_data = emp_data[(emp_data.emp_age >= 25) & (emp_data.emp_age <= 40)]
emp_data = emp_data.sort_values("emp_id")

print(emp_data.tail(3))
# Out:
#     emp_id  emp_age                 role
# 39     140       25      Sales Executive
# 40     141       39  Marketing Executive
# 48     149       31     Digital Marketer

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
hr = df[df["role"].str.contains("HR")]

print(hr)
print("Total HR:", len(hr))
# Out:
#     emp_id  emp_age  emp_salary          role
# 0      101       54       51725    HR Manager
# 5      106       37       58915    HR Manager
# 9      110       38       90494  HR Executive
# 24     125       53       60584  HR Executive
# 27     128       21       71888  HR Executive
# 38     139       27       52013    HR Manager
# 42     143       47       55523  HR Executive
# 44     145       22       90794  HR Executive
# 45     146       52       41061    HR Manager
# Total HR: 9

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
Data_Sort_top_5 = df.sort_values(
    ["emp_age", "emp_salary"], ascending=[True, False])[["emp_id", "role", "emp_salary"]].head(5)

print(Data_Sort_top_5)
# Out:
#     emp_id                role  emp_salary
# 30     131     Sales Executive       82550
# 18     119  Software Developer       63187
# 41     142    Digital Marketer       59500
# 2      103  Operations Manager       35452
# 36     137     Sales Executive       94427

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
df["prev_salary"] = df["emp_salary"]

df["emp_salary"] = np.where(
    df["role"].isin(["Software Developer", "Backend Developer"]),
    df["emp_salary"] * 1.12,
    df["emp_salary"] * 1.05
)

df["new_salary"] = df["emp_salary"]
df["increase"] = df["new_salary"] - df["prev_salary"]

print(df[["role", "prev_salary", "new_salary", "increase"]])
# Out:
#                    role    prev_salary     new_salary      increase
# 0            HR Manager   84254.574570   88467.303299   4212.728729
# 1            Accountant   62704.298658   65839.513591   3135.214933
# 2    Operations Manager   57747.572309   60634.950924   2887.378615
# 3      Digital Marketer  134049.883311  140752.377476   6702.494166
# 4     Backend Developer  224201.864616  251106.088370  26904.223754
# 5            HR Manager   95966.326937  100764.643283   4798.316347
# 6     Backend Developer  236538.293699  264922.888943  28384.595244
# 7       Sales Executive  151265.670621  158828.954152   7563.283531
# 8       Sales Executive  124048.470302  130250.893817   6202.423515
# 9          HR Executive  147405.190356  154775.449873   7370.259518
# 10    Backend Developer  213188.526869  238771.150093  25582.623224
# 11  Marketing Executive   78315.624761   82231.405999   3915.781238
# 12      Sales Executive   92649.897476   97282.392350   4632.494874
# ...
