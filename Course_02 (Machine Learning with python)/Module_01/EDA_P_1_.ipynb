# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('titanic_data_updated.csv')

# %% [markdown]
# ### 2. Analytical View of a Dataset

# %%
df.shape

print(f"Total potential features :{df.shape[1]}")
print(f"Total sample data :{df.shape[0]}")
# Out:
# Total potential features :12
# Total sample data :891

# %%
df.head(10)

df.sample(10)
# Out:
#      PassengerId Survived  Pclass                                     Name  \
# 316          317      yes  second      Kantor, Mrs. Sinai (Miriam Sternin)
# 810          811       no   third                   Alexander, Mr. William
# 173          174       no   third                Sivola, Mr. Antti Wilhelm
# 848          849       no  second                        Harper, Rev. John
# 656          657       no   third                    Radeff, Mr. Alexander
# 367          368      yes   third           Moussa, Mrs. (Mantoura Boulos)
# 819          820       no   third             Skoog, Master. Karl Thorsten
# 850          851       no   third  Andersson, Master. Sigvard Harald Elias
# 480          481       no   third           Goodwin, Master. Harold Victor
# 314          315       no  second                       Hart, Mr. Benjamin
#
#         Sex   Age  SibSp  Parch             Ticket     Fare Cabin Embarked
# 316  female  24.0      1      0             244367  26.0000   NaN        S
# 810    male  26.0      0      0               3474   7.8875   NaN        S
# 173    male  21.0      0      0  STON/O 2. 3101280   7.9250   NaN        S
# 848    male  28.0      0      1             248727  33.0000   NaN        S
# 656    male   NaN      0      0             349223   7.8958   NaN        S
# 367  female   NaN      0      0               2626   7.2292   NaN        C
# 819    male  10.0      3      2             347088  27.9000   NaN        S
# 850    male   4.0      4      2             347082  31.2750   NaN        S
# 480    male   9.0      5      2            CA 2144  46.9000   NaN        S
# 314    male  43.0      1      1       F.C.C. 13529  26.2500   NaN        S

# %% [markdown]
# Feature Screening

# %% [markdown]
# ### 3. Feature Screening

# %%
# missing

df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
# checking duplicates
df.duplicated().sum()

df.drop_duplicates(inplace=True)

# %% [markdown]
# S

# %% [markdown]
# ### 4. Statistical Profiling

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    object
#  2   Pclass       891 non-null    object
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(3), object(7)
# memory usage: 83.7+ KB

# %%
df.describe()
# Out:
#        PassengerId         Age       SibSp       Parch        Fare
# count   891.000000  714.000000  891.000000  891.000000  891.000000
# mean    446.000000   29.699118    0.523008    0.381594   32.204208
# std     257.353842   14.526497    1.102743    0.806057   49.693429
# min       1.000000    0.420000    0.000000    0.000000    0.000000
# 25%     223.500000   20.125000    0.000000    0.000000    7.910400
# 50%     446.000000   28.000000    0.000000    0.000000   14.454200
# 75%     668.500000   38.000000    1.000000    0.000000   31.000000
# max     891.000000   80.000000    8.000000    6.000000  512.329200

# %% [markdown]
# demo

# %% [markdown]
# ### 5. Univariate Analysis( Categorical Value Analysis -1 )

# %%
sns.countplot(data = df , x=df['Survived'])
# Out:
# <Axes: xlabel='Survived', ylabel='count'>

# %%
(df['Survived'].value_counts() / len(df) ) * 100
# Out:
# Survived
# no     61.616162
# yes    38.383838
# Name: count, dtype: float64

# %%
survived_count =  df['Survived'].value_counts()

survived_label = df['Survived'].unique()

plt.pie(survived_count, labels = survived_label, autopct="%1.1f")
plt.title('Pie chart of survival rate')
plt.show()

# %% [markdown]
# ### 6. Univariate Analysis( Categorical Value Analysis -2)

# %%
sns.countplot(data = df , x=df['Pclass'])
# Out:
# <Axes: xlabel='Pclass', ylabel='count'>

# %%
(df['Pclass'].value_counts() / len(df) ) * 100
# Out:
# Pclass
# third     55.106622
# first     24.242424
# second    20.650954
# Name: count, dtype: float64

# %%
sns.countplot(data = df , x=df['Sex'])
# Out:
# <Axes: xlabel='Sex', ylabel='count'>

# %%
(df['Sex'].value_counts() / len(df) ) * 100
# Out:
# Sex
# male      64.758698
# female    35.241302
# Name: count, dtype: float64

# %%
sns.countplot(data = df , x=df['Embarked'])
# Out:
# <Axes: xlabel='Embarked', ylabel='count'>

# %%
(df['Embarked'].value_counts() / len(df) ) * 100
# Out:
# Embarked
# S    72.278339
# C    18.855219
# Q     8.641975
# Name: count, dtype: float64

# %% [markdown]
# demo

# %% [markdown]
# ### 7.Univariate Analysis ( Numerical Column Analysis - 1)

# %%
sns.histplot(df['Age'],bins=50)

plt.title('Histogram of Age')
plt.xlabel('Ages')
plt.ylabel('frequency')

plt.show()

# %%
sns.kdeplot(df['Age'])
plt.title('KDE plot of Age')
plt.xlabel('Ages')
plt.ylabel('probabilty distribution')

plt.show()

# %% [markdown]
# ### 8.Univariate Analysis ( Numerical Column Analysis - 2)

# %%
sns.histplot(df['Fare'],bins=50)

plt.title('Histogram of Fare')
plt.xlabel('Fare')
plt.ylabel('frequency')

plt.show()

# %%
sns.kdeplot(df['Fare'])
plt.title('KDE plot of Fare')
plt.xlabel('Fare')
plt.ylabel('probabilty distribution')

plt.show()

# %%
sns.boxplot(df['Fare'])
# Out:
# <Axes: ylabel='Fare'>
