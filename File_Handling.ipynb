# %% [markdown]
# <a href="https://colab.research.google.com/github/tanzimahamed/Phitron-AI-Programming-With-Python-Batch-2/blob/main/File_Handling.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
file = open("./sample_data/sample.txt","r")
content = file.read()
print(content)
# Out:
# My name is Tanzim
# My University is DIU

# %%
file = open("./sample_data/sample.txt","r")
content = file.readlines()     # list create korbe New line r opore
print(content)
# Out:
# ['My name is Tanzim\n', 'My University is DIU']

# %%
file = open("./sample_data/sample.txt","r")
content = file.read()
print(content)
print(type(content))

file.close()

print (file.closed)
# Out:
# My name is Tanzim
# My University is DIU
# <class 'str'>
# True

# %%
with  open("./sample_data/sample.txt","r") as file:
  content = file.read()
print(content)
print(type(content))


print(file.closed)
# Out:
# My name is Tanzim
# My University is DIU
# <class 'str'>
# True

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
with  open("./sample_data/sample.txt","r") as file:
  for line in file:
    # print(line)

    print(line,end="")
# Out:
# My Nmane is Tanzim Ahamed
# My University Name is DEffodil International University
# I want to be a Al/ML expart

# %%
import os
print(os.listdir("./sample_data"))
# Out:
# ['README.md', 'anscombe.json', '.ipynb_checkpoints', 'california_housing_test.csv', 'mnist_train_small.csv', 'mnist_test.csv', 'california_housing_train.csv']

# %%
with open("./sample_data/sample.txt", "w") as f:
    f.write("My name is Tanzim\nMy University is DIU")

# %%
import os
print(os.listdir("./sample_data"))
# Out:
# ['README.md', 'anscombe.json', '.ipynb_checkpoints', 'sample.txt', 'california_housing_test.csv', 'mnist_train_small.csv', 'mnist_test.csv', 'california_housing_train.csv']

# %%
#Createing a new File & writing File
with open ("./sample_data/text.txt","w" )as file :
  file.write("Hello Test File\n")
  file.write("How is learing going on ?")

# %%
#writing on existing file
#it overwrite the file
with open ("./sample_data/text.txt","w" )as file :
  file.write("Secend attempt\n")
  file.write("learing going frist\n?")

# %%
# No overwriting
# append mode
with open ("./sample_data/text.txt","a" )as file :
  file.write("Learning of AI/ML\n")
  file.write("I am enjoying the class ?")
